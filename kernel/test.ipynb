# %%
import numpy as np
import random
from FPU import cmul, cadd
from utils import read_binary, binary_to_fp16, store_binary, generate_fp16

# %%
DATA_PATH = "/net/badwater/z/hyunwon/Documents/_GIT/PROWESS/SIM/PE/DATA/"
OUTPUT_PATH = "/net/badwater/z/hyunwon/Documents/TSMC_Prowess/sim/PE/OUTPUT/"

# %%
kernel = 'fft_0'

golden = binary_to_fp16(read_binary2(DATA_PATH + kernel + "_output.txt"))
result = (binary_to_fp16(read_binary2(OUTPUT_PATH + kernel + "_out2.txt")))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 kernel = 'fft_0'
# ----> 3 golden = binary_to_fp16(read_binary2(DATA_PATH + kernel + "_output.txt"))
#       4 result = (binary_to_fp16(read_binary2(OUTPUT_PATH + kernel + "_out2.txt")))
#
# File ~/Documents/_GIT/PROWESS/SIM/golden_model_kernel/utils.py:37, in binary_to_fp16(binary_str)
#      36 def binary_to_fp16(binary_str):
# ---> 37         sign = int(binary_str[0], 2)
#      38         exponent = int(binary_str[1:6], 2) # exponent treated as unsigned number, so should do e-bias
#      39         mantissa = int(binary_str[6:], 2)
#
# TypeError: int() can't convert non-string with explicit base

# %%
name = DATA_PATH + kernel + "_output.txt"
print(name)
read_binary(name)
# Out:
# /net/badwater/z/hyunwon/Documents/_GIT/PROWESS/SIM/PE/DATA/fft_0_output.txt
# ['00110000011011001011110100100100',
#  '00111110110011001011100010000100',
#  '00111111010111110011110110000111',
#  '00111101101101110011111001101111',
#  '01000010001111100100001010000100',
#  '10101100001100001011100011001110',
#  '00111100111110000100000011010100',
#  '10111110111110000011110010000001',
#  '00111011000010100011111011111111',
#  '00110101011010010100000000101110',
#  '10111100001101100011110101000110',
#  '10111000001011000011011101111100',
#  '01000011100111001010110001000000',
#  '00110001011110000011110011110111',
#  '10111001100000001011001101011100',
#  '10111011110000100011111011110000',
#  '00111001001101100100000100101011',
#  '10111101010100011011110000110010',
#  '00111000110001001011100111001010',
#  '10101011010010001001110111000000',
#  '00110101100111110011110011110100',
#  '00111100000100011011111010100110',
#  '00111010000100000011110101111100',
# ...

# %%
read_binary2(name)
# Out:
# [['0011000001101100', '1011110100100100'],
#  ['0011111011001100', '1011100010000100'],
#  ['0011111101011111', '0011110110000111'],
#  ['0011110110110111', '0011111001101111'],
#  ['0100001000111110', '0100001010000100'],
#  ['1010110000110000', '1011100011001110'],
#  ['0011110011111000', '0100000011010100'],
#  ['1011111011111000', '0011110010000001'],
#  ['0011101100001010', '0011111011111111'],
#  ['0011010101101001', '0100000000101110'],
#  ['1011110000110110', '0011110101000110'],
#  ['1011100000101100', '0011011101111100'],
#  ['0100001110011100', '1010110001000000'],
#  ['0011000101111000', '0011110011110111'],
#  ['1011100110000000', '1011001101011100'],
#  ['1011101111000010', '0011111011110000'],
#  ['0011100100110110', '0100000100101011'],
#  ['1011110101010001', '1011110000110010'],
#  ['0011100011000100', '1011100111001010'],
#  ['1010101101001000', '1001110111000000'],
#  ['0011010110011111', '0011110011110100'],
#  ['0011110000010001', '1011111010100110'],
# ...

# %%
name = OUTPUT_PATH + kernel + "_out2.txt"
print(name)

a = read_binary(name)
b = read_binary2(name)

for i in range(5):
    print(a[i])

for i in range(5):
    print(b[i])
# Out:
# /net/badwater/z/hyunwon/Documents/TSMC_Prowess/sim/PE/OUTPUT/fft_0_out2.txt
# 00000000000000000000000000000000 00000000000000000000000000000000 00000000000000000000000000000000 00000000000000000000000000000000
# 00000000000000000000000000000000 00000000000000000000000000000000 00000000000000000000000000000000 00000000000000000000000000000000
# 00000000000000000000000000000000 00000000000000000000000000000000 00000000000000000000000000000000 00000000000000000000000000000000
# 00000000000000000000000000000000 00000000000000000000000000000000 00000000000000000000000000000000 00000000000000000000000000000000
# 00000000000000000000000000000000 00000000000000000000000000000000 00000000000000000000000000000000 00000000000000000000000000000000
# [['0000000000000000', '0000000000000000'], ['0000000000000000', '0000000000000000'], ['0000000000000000', '0000000000000000'], ['0000000000000000', '0000000000000000']]
# ...
