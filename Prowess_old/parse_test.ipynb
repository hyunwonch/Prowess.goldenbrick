# %%
text = "Here is some text to print and save to a file."
with open("output.txt", "a") as f:
    for j in range(5):
        f.write(text + "\n")
        for i in range(100):
            f.write(f"Line {i + 1}\n")

# %%
# !pip install keyboard
# Out:
# Collecting keyboard
#   Obtaining dependency information for keyboard from https://files.pythonhosted.org/packages/55/88/287159903c5b3fc6d47b651c7ab65a54dcf9c9916de546188a7f62870d6d/keyboard-0.13.5-py3-none-any.whl.metadata
#   Downloading keyboard-0.13.5-py3-none-any.whl.metadata (4.0 kB)
# Downloading keyboard-0.13.5-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.1 kB ? eta -:--:--
#    -------------- ------------------------- 20.5/58.1 kB 640.0 kB/s eta 0:00:01
#    ---------------------------------------- 58.1/58.1 kB 1.0 MB/s eta 0:00:00
# Installing collected packages: keyboard
# Successfully installed keyboard-0.13.5

# %%
import keyboard  # 실시간 키 입력 처리용
import time

class CycleNavigator:
    def __init__(self, filename):
        self.cycles = []
        self.index = 0
        self._load_cycles(filename)

    def _load_cycles(self, filename):
        with open(filename, 'r') as f:
            lines = f.readlines()

        current_cycle = []
        for line in lines:
            line = line.strip()
            if line.startswith("=== CYCLE"):
                if current_cycle:
                    self.cycles.append(current_cycle)
                    current_cycle = []
            elif line != "":
                current_cycle.append(line)
        if current_cycle:
            self.cycles.append(current_cycle)

    def show_current(self):
        print(f"\n--- CYCLE {self.index} ---")
        for line in self.cycles[self.index]:
            print(line)

    def next(self):
        if self.index < len(self.cycles) - 1:
            self.index += 1
            self.show_current()
        else:
            print("\n[Reached end of log]")

    def prev(self):
        if self.index > 0:
            self.index -= 1
            self.show_current()
        else:
            print("\n[At beginning of log]")

    def go_to(self, cycle_number):
        if 0 <= cycle_number < len(self.cycles):
            self.index = cycle_number
            self.show_current()
        else:
            print(f"\n[Invalid cycle number: {cycle_number}]")

    def total_cycles(self):
        return len(self.cycles)


def realtime_viewer(filename):
    nav = CycleNavigator(filename)
    print(f"\n[Simulation Log Loaded] Total Cycles: {nav.total_cycles()}")
    nav.show_current()

    print("\nPress → (right) for next, ← (left) for previous, 'q' to quit.\n")

    while True:
        if keyboard.is_pressed('right'):
            nav.next()
            time.sleep(0.2)  # 너무 빠르게 넘어가는 것 방지
        elif keyboard.is_pressed('left'):
            nav.prev()
            time.sleep(0.2)
        elif keyboard.is_pressed('q'):
            print("Exiting viewer.")
            break


if __name__ == "__main__":
    realtime_viewer("sim.txt")
# Out:
# [Simulation Log Loaded] Total Cycles: 3
#
# --- CYCLE 0 ---
# pc = 0x0000
# instr = 0xdeadbeef
# reg_a = 5
# reg_b = 7
# result = 12
#
# Press → (right) for next, ← (left) for previous, 'q' to quit.
#
#
# --- CYCLE 1 ---
# pc = 0x0004
# instr = 0xfeedface
# reg_a = 8
# reg_b = 3
# result = 11
#
# --- CYCLE 0 ---
# pc = 0x0000
# instr = 0xdeadbeef
# reg_a = 5
# reg_b = 7
# result = 12
#
# --- CYCLE 1 ---
# pc = 0x0004
# instr = 0xfeedface
# reg_a = 8
# reg_b = 3
# result = 11
#
# --- CYCLE 2 ---
# pc = 0x0008
# instr = 0x12345678
# reg_a = 2
# reg_b = 2
# result = 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 76
#      72             break
#      75 if __name__ == "__main__":
# ---> 76     realtime_viewer("sim.txt")
#
# Cell In[8], line 67, in realtime_viewer(filename)
#      65     nav.next()
#      66     time.sleep(0.2)  # 너무 빠르게 넘어가는 것 방지
# ---> 67 elif keyboard.is_pressed('left'):
#      68     nav.prev()
#      69     time.sleep(0.2)
#
# File c:\Users\hyunwon\AppData\Local\anaconda3\Lib\site-packages\keyboard\__init__.py:417, in is_pressed(hotkey)
#     414     with _pressed_events_lock:
#     415         return hotkey in _pressed_events
# --> 417 steps = parse_hotkey(hotkey)
#     418 if len(steps) > 1:
#     419     raise ValueError("Impossible to check if multi-step hotkeys are pressed (`a+b` is ok, `a, b` isn't).")
#
# File c:\Users\hyunwon\AppData\Local\anaconda3\Lib\site-packages\keyboard\__init__.py:358, in parse_hotkey(hotkey)
#     356 for step in _re.split(r',\s?', hotkey):
#     357     keys = _re.split(r'\s?\+\s?', step)
# --> 358     steps.append(tuple(key_to_scan_codes(key) for key in keys))
#     359 return tuple(steps)
#
# File c:\Users\hyunwon\AppData\Local\anaconda3\Lib\site-packages\keyboard\__init__.py:358, in <genexpr>(.0)
#     356 for step in _re.split(r',\s?', hotkey):
#     357     keys = _re.split(r'\s?\+\s?', step)
# --> 358     steps.append(tuple(key_to_scan_codes(key) for key in keys))
#     359 return tuple(steps)
#
# File c:\Users\hyunwon\AppData\Local\anaconda3\Lib\site-packages\keyboard\__init__.py:317, in key_to_scan_codes(key, error_if_missing)
#     313     return left_scan_codes + tuple(c for c in right_scan_codes if c not in left_scan_codes)
#     315 try:
#     316     # Put items in ordered dict to remove duplicates.
# --> 317     t = tuple(_collections.OrderedDict((scan_code, True) for scan_code, modifier in _os_keyboard.map_name(normalized)))
#     318     e = None
#     319 except (KeyError, ValueError) as exception:
#
# File c:\Users\hyunwon\AppData\Local\anaconda3\Lib\site-packages\keyboard\__init__.py:317, in <genexpr>(.0)
#     313     return left_scan_codes + tuple(c for c in right_scan_codes if c not in left_scan_codes)
#     315 try:
#     316     # Put items in ordered dict to remove duplicates.
# --> 317     t = tuple(_collections.OrderedDict((scan_code, True) for scan_code, modifier in _os_keyboard.map_name(normalized)))
#     318     e = None
#     319 except (KeyError, ValueError) as exception:
#
# KeyboardInterrupt:
