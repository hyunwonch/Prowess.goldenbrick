# %% [markdown]
# # FP16 Verification

# %%
import numpy as np
import random
import math

# %% [markdown]
# ## Function definition

# %%
# Function to generate random FP16 binary strings
def generate_random_fp16():
    sign = random.choice(['0', '1'])
    exponent = format(random.randint(0, 31), '05b')  # 5-bit exponent
    mantissa = format(random.randint(0, 1023), '010b')  # 10-bit mantissa
    return sign + exponent + mantissa

# %%
class FP16AdderGoldenModel:
    def __init__(self, rounding_mode="nearest", ieee_mode="standard"):
        self.rounding_mode = rounding_mode
        self.ieee_mode = ieee_mode

    def binary_to_fp16(self, binary_str):
        sign = int(binary_str[0], 2)
        exponent = int(binary_str[1:6], 2) # exponent treated as unsigned number, so should do e-bias
        mantissa = int(binary_str[6:], 2)

        if exponent == 0 and mantissa == 0:
            return 0.0 if sign == 0 else -0.0
        elif exponent == 31:
            if mantissa == 0:
                return float('inf') if sign == 0 else float('-inf')
            else:
                if self.ieee_mode == "standard":
                    return float('nan')
                else:
                    return float('inf') if sign == 0 else float('-inf')

        exponent = exponent - 15
        if exponent < -14:
            if self.ieee_mode == "simplified":
                return +0.0 if sign == 0 else -0.0
            value = ((-1) ** sign) * (mantissa / (2 ** 10)) * (2 ** -14)
        else:
            value = ((-1) ** sign) * ((mantissa / (2 ** 10)) + 1.0) * (2 ** exponent)

        return value

    def fp16_to_binary(self, value):

        if np.isnan(value):
            return "0111111111111111"

        if np.isposinf(value):
            return "0111110000000000" # inf

        if np.isneginf(value):
            return "1111110000000000" # -inf

        if value == 0.0:
            return "1000000000000000" if math.copysign(1.0, value) == -1.0 else "0000000000000000"

        sign = 0 if value > 0 else 1
        value = abs(value)

        exponent = np.floor(np.log2(value)) + 15
        exponent = min(max(exponent, 0), 31)


        # mantissa = (value / (2 ** (exponent - 15))) - 1.0
        # mantissa_bits = int(mantissa * (2 ** 10)) & 0b1111111111

        mantissa = round((value / (2 ** (exponent - 15))) - 1.0, 10)
        # print(mantissa)
        mantissa_int = int(mantissa * (2 ** 10) + 0.5)
        # print(mantissa_int)
        if mantissa_int == 2 ** 10:
            exponent = exponent + 1 # Used to Update the exp since the mantissa may overflow under nearest rounding
        exponent_bits = int(exponent) & 0b11111
        mantissa_bits = mantissa_int & 0b1111111111
        # print(mantissa_bits)

        binary_str = f"{sign:01b}{exponent_bits:05b}{mantissa_bits:010b}"
        return binary_str

    def add(self, a_value, b_value):

        # Perform the actual addition
        if (math.isinf(a_value) and math.isinf(b_value)) and (math.copysign(1.0, a_value) != math.copysign(1.0, b_value)):
            result = float('inf')
        else:
            result = a_value + b_value

        # Manually handle overflow to the Maximum
        if math.isnan(result) or math.isinf(result):
            return float('inf') if math.copysign(1.0, result) == 1 else float('-inf')

        if result > (2 ** 16) or result < (-2 ** 16):
            return float('inf') if math.copysign(1.0, result) == 1 else float('-inf')

        if self.ieee_mode == "simplified":
            if abs(result) < (2 ** -14):
                return -0.0 if math.copysign(1.0, result) == -1 else 0.0

        return result


adder = FP16AdderGoldenModel(rounding_mode="nearest", ieee_mode="simplified")

# %%
def binary_to_fp16(binary_str):
    # 1. 문자열 → 정수
    uint16_val = int(binary_str, 2)

    # 2. 정수 → np.uint16
    np_uint16 = np.uint16(uint16_val)

    # 3. uint16을 float16으로 재해석
    float16_val = np.frombuffer(np_uint16.tobytes(), dtype=np.float16)[0]

    return float16_val

# %% [markdown]
# ## Compare two function (custom vs np.float16)

# %%
for i in range(10000):
    # # 1. 랜덤 binary string 생성
    # a = generate_random_fp16()

    # # 2. custom 함수로 binary → float16
    # a_value = adder.binary_to_fp16(a)


    a_value = np.float16(random.random())

    # 3. numpy 기반 binary 추출
    a_float16 = np.float16(a_value)
    a_bin_numpy = format(a_float16.view(np.uint16), '016b')

    # 4. custom 함수로 float16 → binary
    a_bin_custom = adder.fp16_to_binary(a_value)

    # 5. 비교 출력
    if a_bin_custom == a_bin_numpy:
        # print(f"[{i:02}] ✅ Match: {a_bin_custom}")
        pass
    else:
        print(f"[{i:02}] ❌ Mismatch:")
        print(f"     Input binary       : {a}")
        print(f"     Float16 value       : {a_value}")
        print(f"     Custom binary       : {a_bin_custom}")
        print(f"     Numpy binary        : {a_bin_numpy}")
# Out:
# [3335] ❌ Mismatch:
#      Input binary       : 1010010100010111
#      Float16 value       : 0.0038967132568359375
#      Custom binary       : 0001111111111111
#      Numpy binary        : 0001101111111011
# [5931] ❌ Mismatch:
#      Input binary       : 1010010100010111
#      Float16 value       : 0.062469482421875
#      Custom binary       : 0010110000000000
#      Numpy binary        : 0010101111111111
# [9531] ❌ Mismatch:
#      Input binary       : 1010010100010111
#      Float16 value       : 5.9485435485839844e-05
#      Custom binary       : 0000001111001100
#      Numpy binary        : 0000001111100110

# %% [markdown]
# ## custom binary_to_fp16 function cannot generate correct binary value

# %%
for i in range(10000):
    # 1. 랜덤 binary string 생성
    a = generate_random_fp16()

    # 2. custom 함수로 binary → float16
    a_value = adder.binary_to_fp16(a)


    # a_value = np.float16(random.random())

    # 3. numpy 기반 binary 추출
    # a_float16 = np.float16(a_value)
    a_float16 = binary_to_fp16(a)

    a_bin_numpy = format(a_float16.view(np.uint16), '016b')

    # 4. custom 함수로 float16 → binary
    a_bin_custom = adder.fp16_to_binary(a_value)

    # 5. 비교 출력
    if a_bin_custom == a_bin_numpy:
        # print(f"[{i:02}] ✅ Match: {a_bin_custom}")
        pass
    else:
        print(f"[{i:02}] ❌ Mismatch:")
        print(f"     Input binary       : {a}")
        print(f"     Float16 value       : {a_value}")
        print(f"     Custom binary       : {a_bin_custom}")
        print(f"     Numpy binary        : {a_bin_numpy}")
# Out:
# [01] ❌ Mismatch:
#      Input binary       : 1111110001000010
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110001000010
# [14] ❌ Mismatch:
#      Input binary       : 0111110000001101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110000001101
# [21] ❌ Mismatch:
#      Input binary       : 0111111001110001
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111001110001
# [23] ❌ Mismatch:
#      Input binary       : 1000000101011010
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000101011010
# [36] ❌ Mismatch:
#      Input binary       : 0000000000001011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000000001011
# [56] ❌ Mismatch:
#      Input binary       : 1000001101101101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001101101101
# [61] ❌ Mismatch:
#      Input binary       : 0111111010001100
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111010001100
# [81] ❌ Mismatch:
#      Input binary       : 1000000010100111
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000010100111
# [106] ❌ Mismatch:
#      Input binary       : 0111110010010010
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110010010010
# [135] ❌ Mismatch:
#      Input binary       : 1000000010100010
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000010100010
# [155] ❌ Mismatch:
#      Input binary       : 0000001100110101
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001100110101
# [157] ❌ Mismatch:
#      Input binary       : 0111111000111011
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111000111011
# [170] ❌ Mismatch:
#      Input binary       : 0000000000101000
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000000101000
# [180] ❌ Mismatch:
#      Input binary       : 0111111100111010
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111100111010
# [200] ❌ Mismatch:
#      Input binary       : 1111110100001100
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110100001100
# [205] ❌ Mismatch:
#      Input binary       : 0000000110010101
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000110010101
# [214] ❌ Mismatch:
#      Input binary       : 1111110001010001
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110001010001
# [232] ❌ Mismatch:
#      Input binary       : 0111110000100101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110000100101
# [245] ❌ Mismatch:
#      Input binary       : 0111111000111111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111000111111
# [246] ❌ Mismatch:
#      Input binary       : 1000000110110110
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000110110110
# [290] ❌ Mismatch:
#      Input binary       : 1111111001010111
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111001010111
# [296] ❌ Mismatch:
#      Input binary       : 0000001100110110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001100110110
# [300] ❌ Mismatch:
#      Input binary       : 1000001001110110
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001001110110
# [302] ❌ Mismatch:
#      Input binary       : 0111110011110010
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110011110010
# [314] ❌ Mismatch:
#      Input binary       : 1111110111000011
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110111000011
# [323] ❌ Mismatch:
#      Input binary       : 0000000011111001
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000011111001
# [331] ❌ Mismatch:
#      Input binary       : 1000000111110010
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000111110010
# [342] ❌ Mismatch:
#      Input binary       : 1000000000011101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000000011101
# [380] ❌ Mismatch:
#      Input binary       : 0000000001011011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000001011011
# [425] ❌ Mismatch:
#      Input binary       : 1111110100110101
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110100110101
# [427] ❌ Mismatch:
#      Input binary       : 0111111110110111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111110110111
# [442] ❌ Mismatch:
#      Input binary       : 1000000111000000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000111000000
# [445] ❌ Mismatch:
#      Input binary       : 1000001101010001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001101010001
# [448] ❌ Mismatch:
#      Input binary       : 1111111011001100
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111011001100
# [456] ❌ Mismatch:
#      Input binary       : 0000001001011001
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001001011001
# [497] ❌ Mismatch:
#      Input binary       : 0000000100011100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000100011100
# [498] ❌ Mismatch:
#      Input binary       : 1111110010111101
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110010111101
# [550] ❌ Mismatch:
#      Input binary       : 0000000111100100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000111100100
# [571] ❌ Mismatch:
#      Input binary       : 0000001011110001
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001011110001
# [588] ❌ Mismatch:
#      Input binary       : 0111111001101111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111001101111
# [604] ❌ Mismatch:
#      Input binary       : 0111111101010000
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111101010000
# [613] ❌ Mismatch:
#      Input binary       : 1111111111011011
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111111011011
# [615] ❌ Mismatch:
#      Input binary       : 0000000110001110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000110001110
# [622] ❌ Mismatch:
#      Input binary       : 0000001010101110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001010101110
# [630] ❌ Mismatch:
#      Input binary       : 1111110111101111
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110111101111
# [638] ❌ Mismatch:
#      Input binary       : 0000001101110100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001101110100
# [674] ❌ Mismatch:
#      Input binary       : 1000000001101000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000001101000
# [789] ❌ Mismatch:
#      Input binary       : 1000001000100101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001000100101
# [790] ❌ Mismatch:
#      Input binary       : 0111110001001111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110001001111
# [802] ❌ Mismatch:
#      Input binary       : 1000000000111010
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000000111010
# [804] ❌ Mismatch:
#      Input binary       : 1111111000000111
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111000000111
# [826] ❌ Mismatch:
#      Input binary       : 0111110001110000
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110001110000
# [830] ❌ Mismatch:
#      Input binary       : 0000001001101111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001001101111
# [843] ❌ Mismatch:
#      Input binary       : 1000000011100000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000011100000
# [853] ❌ Mismatch:
#      Input binary       : 1000000101010101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000101010101
# [854] ❌ Mismatch:
#      Input binary       : 1111111010100010
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111010100010
# [857] ❌ Mismatch:
#      Input binary       : 0111111000001101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111000001101
# [859] ❌ Mismatch:
#      Input binary       : 1000001100111101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001100111101
# [862] ❌ Mismatch:
#      Input binary       : 0000001110000111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001110000111
# [892] ❌ Mismatch:
#      Input binary       : 0111111100001101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111100001101
# [915] ❌ Mismatch:
#      Input binary       : 0000000110010010
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000110010010
# [918] ❌ Mismatch:
#      Input binary       : 0000000011100110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000011100110
# [930] ❌ Mismatch:
#      Input binary       : 1000001110000011
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001110000011
# [941] ❌ Mismatch:
#      Input binary       : 1000000101001001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000101001001
# [947] ❌ Mismatch:
#      Input binary       : 1000000000010001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000000010001
# [960] ❌ Mismatch:
#      Input binary       : 1111111101101000
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111101101000
# [976] ❌ Mismatch:
#      Input binary       : 1000001010101110
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001010101110
# [995] ❌ Mismatch:
#      Input binary       : 1111111011000101
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111011000101
# [1017] ❌ Mismatch:
#      Input binary       : 1111111101011011
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111101011011
# [1018] ❌ Mismatch:
#      Input binary       : 1000000000001111
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000000001111
# [1033] ❌ Mismatch:
#      Input binary       : 1000001111010001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001111010001
# [1038] ❌ Mismatch:
#      Input binary       : 1000000001001011
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000001001011
# [1050] ❌ Mismatch:
#      Input binary       : 1111110001000110
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110001000110
# [1074] ❌ Mismatch:
#      Input binary       : 1000000110000011
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000110000011
# [1077] ❌ Mismatch:
#      Input binary       : 1000000011111010
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000011111010
# [1081] ❌ Mismatch:
#      Input binary       : 1000001110111000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001110111000
# [1102] ❌ Mismatch:
#      Input binary       : 0111110001100001
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110001100001
# [1131] ❌ Mismatch:
#      Input binary       : 1000000100000111
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000100000111
# [1139] ❌ Mismatch:
#      Input binary       : 1111111101111001
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111101111001
# [1152] ❌ Mismatch:
#      Input binary       : 0000000000101011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000000101011
# [1171] ❌ Mismatch:
#      Input binary       : 0000001001010011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001001010011
# [1173] ❌ Mismatch:
#      Input binary       : 1111110010111110
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110010111110
# [1181] ❌ Mismatch:
#      Input binary       : 1111110100101110
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110100101110
# [1196] ❌ Mismatch:
#      Input binary       : 0111110011100000
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110011100000
# [1201] ❌ Mismatch:
#      Input binary       : 1111110000001011
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110000001011
# [1207] ❌ Mismatch:
#      Input binary       : 0111110100100011
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110100100011
# [1241] ❌ Mismatch:
#      Input binary       : 0000000110001100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000110001100
# [1243] ❌ Mismatch:
#      Input binary       : 1000000100001011
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000100001011
# [1279] ❌ Mismatch:
#      Input binary       : 0000001001011011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001001011011
# [1339] ❌ Mismatch:
#      Input binary       : 0000000011001000
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000011001000
# [1350] ❌ Mismatch:
#      Input binary       : 1111110100111000
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110100111000
# [1391] ❌ Mismatch:
#      Input binary       : 1000001011011101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001011011101
# [1404] ❌ Mismatch:
#      Input binary       : 1111110110001110
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110110001110
# [1440] ❌ Mismatch:
#      Input binary       : 0000001001111001
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001001111001
# [1449] ❌ Mismatch:
#      Input binary       : 0111110010001000
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110010001000
# [1451] ❌ Mismatch:
#      Input binary       : 0000000010111110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000010111110
# [1457] ❌ Mismatch:
#      Input binary       : 1111111011011111
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111011011111
# [1458] ❌ Mismatch:
#      Input binary       : 1000001101110101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001101110101
# [1459] ❌ Mismatch:
#      Input binary       : 0111110011000111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110011000111
# [1471] ❌ Mismatch:
#      Input binary       : 0111111101111101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111101111101
# [1478] ❌ Mismatch:
#      Input binary       : 1000001010000001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001010000001
# [1493] ❌ Mismatch:
#      Input binary       : 0000001011000111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001011000111
# [1540] ❌ Mismatch:
#      Input binary       : 1000001010110100
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001010110100
# [1549] ❌ Mismatch:
#      Input binary       : 0000001100110111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001100110111
# [1568] ❌ Mismatch:
#      Input binary       : 0000001000010111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001000010111
# [1603] ❌ Mismatch:
#      Input binary       : 0111110011000011
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110011000011
# [1606] ❌ Mismatch:
#      Input binary       : 0111110110101010
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110110101010
# [1646] ❌ Mismatch:
#      Input binary       : 0000000000011010
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000000011010
# [1666] ❌ Mismatch:
#      Input binary       : 0000000000100010
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000000100010
# [1681] ❌ Mismatch:
#      Input binary       : 1000000111001101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000111001101
# [1689] ❌ Mismatch:
#      Input binary       : 0111111011011111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111011011111
# [1701] ❌ Mismatch:
#      Input binary       : 0111110000001010
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110000001010
# [1762] ❌ Mismatch:
#      Input binary       : 1000001100000101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001100000101
# [1777] ❌ Mismatch:
#      Input binary       : 0111111010010100
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111010010100
# [1779] ❌ Mismatch:
#      Input binary       : 0000001010101100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001010101100
# [1792] ❌ Mismatch:
#      Input binary       : 0111110111011100
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110111011100
# [1809] ❌ Mismatch:
#      Input binary       : 0000001001000110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001001000110
# [1849] ❌ Mismatch:
#      Input binary       : 1111110110111100
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110110111100
# [1855] ❌ Mismatch:
#      Input binary       : 1000000010100000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000010100000
# [1857] ❌ Mismatch:
#      Input binary       : 1111110101001010
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110101001010
# [1883] ❌ Mismatch:
#      Input binary       : 1000000010001000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000010001000
# [1895] ❌ Mismatch:
#      Input binary       : 1111111111100011
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111111100011
# [1907] ❌ Mismatch:
#      Input binary       : 1111110010010000
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110010010000
# [1915] ❌ Mismatch:
#      Input binary       : 0000000100000011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000100000011
# [1937] ❌ Mismatch:
#      Input binary       : 1111111101000001
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111101000001
# [1947] ❌ Mismatch:
#      Input binary       : 0000001010011100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001010011100
# [1949] ❌ Mismatch:
#      Input binary       : 0000001010000110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001010000110
# [1950] ❌ Mismatch:
#      Input binary       : 1000000110001110
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000110001110
# [1956] ❌ Mismatch:
#      Input binary       : 0000001110100100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001110100100
# [1962] ❌ Mismatch:
#      Input binary       : 0000000101011000
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000101011000
# [1966] ❌ Mismatch:
#      Input binary       : 1111110011001110
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110011001110
# [1990] ❌ Mismatch:
#      Input binary       : 0111111011101011
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111011101011
# [2022] ❌ Mismatch:
#      Input binary       : 1000001011111001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001011111001
# [2048] ❌ Mismatch:
#      Input binary       : 1000000111011010
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000111011010
# [2056] ❌ Mismatch:
#      Input binary       : 1111110000101110
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110000101110
# [2077] ❌ Mismatch:
#      Input binary       : 0000000011100010
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000011100010
# [2105] ❌ Mismatch:
#      Input binary       : 1000001010111110
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001010111110
# [2109] ❌ Mismatch:
#      Input binary       : 1000000010010011
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000010010011
# [2114] ❌ Mismatch:
#      Input binary       : 1111111100001110
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111100001110
# [2125] ❌ Mismatch:
#      Input binary       : 0000000101001111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000101001111
# [2144] ❌ Mismatch:
#      Input binary       : 0111110111110001
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110111110001
# [2211] ❌ Mismatch:
#      Input binary       : 1000001100000100
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001100000100
# [2220] ❌ Mismatch:
#      Input binary       : 0000000111001011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000111001011
# [2237] ❌ Mismatch:
#      Input binary       : 1111110010011110
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110010011110
# [2240] ❌ Mismatch:
#      Input binary       : 1000000110001000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000110001000
# [2247] ❌ Mismatch:
#      Input binary       : 0111111100011100
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111100011100
# [2263] ❌ Mismatch:
#      Input binary       : 0111111110101001
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111110101001
# [2270] ❌ Mismatch:
#      Input binary       : 0000000111101111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000111101111
# [2273] ❌ Mismatch:
#      Input binary       : 1000000010100110
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000010100110
# [2276] ❌ Mismatch:
#      Input binary       : 1000001110101001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001110101001
# [2289] ❌ Mismatch:
#      Input binary       : 1000001000110110
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001000110110
# [2301] ❌ Mismatch:
#      Input binary       : 1111111110011010
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111110011010
# [2307] ❌ Mismatch:
#      Input binary       : 0000001110100111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001110100111
# [2354] ❌ Mismatch:
#      Input binary       : 0111111101010110
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111101010110
# [2357] ❌ Mismatch:
#      Input binary       : 1000000100000011
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000100000011
# [2358] ❌ Mismatch:
#      Input binary       : 1000001000111011
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001000111011
# [2389] ❌ Mismatch:
#      Input binary       : 1000001000000111
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001000000111
# [2424] ❌ Mismatch:
#      Input binary       : 0000000001011011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000001011011
# [2432] ❌ Mismatch:
#      Input binary       : 0111111010101000
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111010101000
# [2450] ❌ Mismatch:
#      Input binary       : 1000000100101001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000100101001
# [2453] ❌ Mismatch:
#      Input binary       : 1000000011000110
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000011000110
# [2467] ❌ Mismatch:
#      Input binary       : 1000001100000001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001100000001
# [2503] ❌ Mismatch:
#      Input binary       : 0000001100101001
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001100101001
# [2507] ❌ Mismatch:
#      Input binary       : 1000001010101100
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001010101100
# [2530] ❌ Mismatch:
#      Input binary       : 1111110100100011
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110100100011
# [2539] ❌ Mismatch:
#      Input binary       : 0111110111011010
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110111011010
# [2553] ❌ Mismatch:
#      Input binary       : 0000001111001111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001111001111
# [2573] ❌ Mismatch:
#      Input binary       : 1111110010111100
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110010111100
# [2580] ❌ Mismatch:
#      Input binary       : 1111111100110000
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111100110000
# [2586] ❌ Mismatch:
#      Input binary       : 0000000100110001
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000100110001
# [2596] ❌ Mismatch:
#      Input binary       : 0111111000011111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111000011111
# [2600] ❌ Mismatch:
#      Input binary       : 1111110000000111
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110000000111
# [2629] ❌ Mismatch:
#      Input binary       : 0000000111101101
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000111101101
# [2630] ❌ Mismatch:
#      Input binary       : 0000000101011100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000101011100
# [2637] ❌ Mismatch:
#      Input binary       : 1000000011100111
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000011100111
# [2648] ❌ Mismatch:
#      Input binary       : 0000000101110101
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000101110101
# [2649] ❌ Mismatch:
#      Input binary       : 0111110110011111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110110011111
# [2653] ❌ Mismatch:
#      Input binary       : 1111111101011000
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111101011000
# [2733] ❌ Mismatch:
#      Input binary       : 0000001100001011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001100001011
# [2765] ❌ Mismatch:
#      Input binary       : 0111110111000000
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110111000000
# [2831] ❌ Mismatch:
#      Input binary       : 0111110111111111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110111111111
# [2888] ❌ Mismatch:
#      Input binary       : 0111111011011101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111011011101
# [2890] ❌ Mismatch:
#      Input binary       : 0000000100100010
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000100100010
# [2893] ❌ Mismatch:
#      Input binary       : 1111110011101101
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110011101101
# [2895] ❌ Mismatch:
#      Input binary       : 1000000001100000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000001100000
# [2918] ❌ Mismatch:
#      Input binary       : 0000001111110110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001111110110
# [2933] ❌ Mismatch:
#      Input binary       : 1000001001001100
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001001001100
# [2958] ❌ Mismatch:
#      Input binary       : 1000000100111111
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000100111111
# [2965] ❌ Mismatch:
#      Input binary       : 1111111100010100
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111100010100
# [2987] ❌ Mismatch:
#      Input binary       : 0111111100100100
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111100100100
# [2999] ❌ Mismatch:
#      Input binary       : 1000001001101000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001001101000
# [3009] ❌ Mismatch:
#      Input binary       : 1000001000101001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001000101001
# [3011] ❌ Mismatch:
#      Input binary       : 1000001001001000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001001001000
# [3022] ❌ Mismatch:
#      Input binary       : 1000001000000010
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001000000010
# [3025] ❌ Mismatch:
#      Input binary       : 0111110101010011
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110101010011
# [3050] ❌ Mismatch:
#      Input binary       : 0111110010100100
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110010100100
# [3073] ❌ Mismatch:
#      Input binary       : 0000001100010111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001100010111
# [3080] ❌ Mismatch:
#      Input binary       : 0000000011010010
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000011010010
# [3084] ❌ Mismatch:
#      Input binary       : 0111110100111011
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110100111011
# [3104] ❌ Mismatch:
#      Input binary       : 0000001111011010
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001111011010
# [3118] ❌ Mismatch:
#      Input binary       : 0000001111111000
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001111111000
# [3124] ❌ Mismatch:
#      Input binary       : 0000001011100110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001011100110
# [3133] ❌ Mismatch:
#      Input binary       : 0000000001101111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000001101111
# [3148] ❌ Mismatch:
#      Input binary       : 0000001010110100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001010110100
# [3156] ❌ Mismatch:
#      Input binary       : 0000001011010100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001011010100
# [3174] ❌ Mismatch:
#      Input binary       : 0000001111000110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001111000110
# [3193] ❌ Mismatch:
#      Input binary       : 0000000101000100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000101000100
# [3207] ❌ Mismatch:
#      Input binary       : 1000001001010101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001001010101
# [3219] ❌ Mismatch:
#      Input binary       : 0111111100101010
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111100101010
# [3229] ❌ Mismatch:
#      Input binary       : 1111111001100011
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111001100011
# [3281] ❌ Mismatch:
#      Input binary       : 0000001001101001
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001001101001
# [3345] ❌ Mismatch:
#      Input binary       : 1111110110011010
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110110011010
# [3352] ❌ Mismatch:
#      Input binary       : 0000001001000100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001001000100
# [3357] ❌ Mismatch:
#      Input binary       : 1000000100111000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000100111000
# [3383] ❌ Mismatch:
#      Input binary       : 1000000110011011
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000110011011
# [3395] ❌ Mismatch:
#      Input binary       : 1111111101101110
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111101101110
# [3421] ❌ Mismatch:
#      Input binary       : 0000001100100011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001100100011
# [3429] ❌ Mismatch:
#      Input binary       : 0111110011000011
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110011000011
# [3453] ❌ Mismatch:
#      Input binary       : 1000001111110111
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001111110111
# [3454] ❌ Mismatch:
#      Input binary       : 1000001110011100
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001110011100
# [3468] ❌ Mismatch:
#      Input binary       : 1111111010000000
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111010000000
# [3482] ❌ Mismatch:
#      Input binary       : 1000000110100000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000110100000
# [3490] ❌ Mismatch:
#      Input binary       : 1000000110101100
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000110101100
# [3528] ❌ Mismatch:
#      Input binary       : 0111110101010101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110101010101
# [3588] ❌ Mismatch:
#      Input binary       : 1000001001111100
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001001111100
# [3593] ❌ Mismatch:
#      Input binary       : 1111111011101111
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111011101111
# [3626] ❌ Mismatch:
#      Input binary       : 1111111001011000
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111001011000
# [3628] ❌ Mismatch:
#      Input binary       : 0000000010110100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000010110100
# [3638] ❌ Mismatch:
#      Input binary       : 0000001101111100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001101111100
# [3645] ❌ Mismatch:
#      Input binary       : 0000001110100100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001110100100
# [3652] ❌ Mismatch:
#      Input binary       : 1000000111111000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000111111000
# [3655] ❌ Mismatch:
#      Input binary       : 0000000100111011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000100111011
# [3660] ❌ Mismatch:
#      Input binary       : 1111110001010000
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110001010000
# [3665] ❌ Mismatch:
#      Input binary       : 1111111111000010
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111111000010
# [3677] ❌ Mismatch:
#      Input binary       : 1111110101011000
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110101011000
# [3698] ❌ Mismatch:
#      Input binary       : 0000001000000000
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001000000000
# [3701] ❌ Mismatch:
#      Input binary       : 0111111011100101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111011100101
# [3714] ❌ Mismatch:
#      Input binary       : 1000000110001010
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000110001010
# [3766] ❌ Mismatch:
#      Input binary       : 1000000110110001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000110110001
# [3807] ❌ Mismatch:
#      Input binary       : 1000000110000001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000110000001
# [3818] ❌ Mismatch:
#      Input binary       : 0111110010010010
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110010010010
# [3826] ❌ Mismatch:
#      Input binary       : 1000001110011000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001110011000
# [3831] ❌ Mismatch:
#      Input binary       : 1000000111010011
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000111010011
# [3848] ❌ Mismatch:
#      Input binary       : 0111110110101011
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110110101011
# [3852] ❌ Mismatch:
#      Input binary       : 0000001011010010
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001011010010
# [3885] ❌ Mismatch:
#      Input binary       : 1000001010111100
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001010111100
# [3890] ❌ Mismatch:
#      Input binary       : 0111111100110011
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111100110011
# [3898] ❌ Mismatch:
#      Input binary       : 1111110010000010
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110010000010
# [3937] ❌ Mismatch:
#      Input binary       : 1000000110001001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000110001001
# [3966] ❌ Mismatch:
#      Input binary       : 1000000100111010
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000100111010
# [3991] ❌ Mismatch:
#      Input binary       : 0111111100011011
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111100011011
# [3996] ❌ Mismatch:
#      Input binary       : 1111110001110011
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110001110011
# [4001] ❌ Mismatch:
#      Input binary       : 1000000011010101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000011010101
# [4008] ❌ Mismatch:
#      Input binary       : 1111110001000101
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110001000101
# [4033] ❌ Mismatch:
#      Input binary       : 1000000000100011
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000000100011
# [4037] ❌ Mismatch:
#      Input binary       : 1111110111001010
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110111001010
# [4044] ❌ Mismatch:
#      Input binary       : 0000001001010100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001001010100
# [4083] ❌ Mismatch:
#      Input binary       : 0111111000110111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111000110111
# [4087] ❌ Mismatch:
#      Input binary       : 0000000110000101
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000110000101
# [4137] ❌ Mismatch:
#      Input binary       : 1000000110101111
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000110101111
# [4141] ❌ Mismatch:
#      Input binary       : 0111110010010000
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110010010000
# [4147] ❌ Mismatch:
#      Input binary       : 0000001111001010
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001111001010
# [4170] ❌ Mismatch:
#      Input binary       : 1000000000101110
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000000101110
# [4179] ❌ Mismatch:
#      Input binary       : 1111110111010110
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110111010110
# [4212] ❌ Mismatch:
#      Input binary       : 0000000010101110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
# ...
# [8624] ❌ Mismatch:
#      Input binary       : 1000000101000101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000101000101
# [8625] ❌ Mismatch:
#      Input binary       : 0000000110101110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000110101110
# [8642] ❌ Mismatch:
#      Input binary       : 1111110110001011
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110110001011
# [8658] ❌ Mismatch:
#      Input binary       : 1111110100110111
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110100110111
# [8669] ❌ Mismatch:
#      Input binary       : 0111110001100001
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110001100001
# [8702] ❌ Mismatch:
#      Input binary       : 0000001011001000
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001011001000
# [8715] ❌ Mismatch:
#      Input binary       : 0000001101011100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001101011100
# [8726] ❌ Mismatch:
#      Input binary       : 0111111011010100
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111011010100
# [8767] ❌ Mismatch:
#      Input binary       : 1000001111010001
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001111010001
# [8788] ❌ Mismatch:
#      Input binary       : 0111110100011101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110100011101
# [8800] ❌ Mismatch:
#      Input binary       : 0111111111000001
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111111000001
# [8801] ❌ Mismatch:
#      Input binary       : 1111111010011111
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111010011111
# [8802] ❌ Mismatch:
#      Input binary       : 0000000001101101
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000001101101
# [8809] ❌ Mismatch:
#      Input binary       : 0000001010100000
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001010100000
# [8818] ❌ Mismatch:
#      Input binary       : 0000000010001010
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000010001010
# [8837] ❌ Mismatch:
#      Input binary       : 1111111111010111
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111111010111
# [8840] ❌ Mismatch:
#      Input binary       : 0000001001101010
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001001101010
# [8846] ❌ Mismatch:
#      Input binary       : 0111110101110101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110101110101
# [8849] ❌ Mismatch:
#      Input binary       : 0111110000110101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110000110101
# [8894] ❌ Mismatch:
#      Input binary       : 0000001011110111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001011110111
# [8901] ❌ Mismatch:
#      Input binary       : 0111110111111100
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110111111100
# [8910] ❌ Mismatch:
#      Input binary       : 1000001011000010
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001011000010
# [8927] ❌ Mismatch:
#      Input binary       : 0000000011110011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000011110011
# [8932] ❌ Mismatch:
#      Input binary       : 0111111010000010
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111010000010
# [8999] ❌ Mismatch:
#      Input binary       : 1111111001010011
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111001010011
# [9015] ❌ Mismatch:
#      Input binary       : 0111111000111101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111000111101
# [9046] ❌ Mismatch:
#      Input binary       : 0111111000011010
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111000011010
# [9061] ❌ Mismatch:
#      Input binary       : 1000000001001011
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000001001011
# [9069] ❌ Mismatch:
#      Input binary       : 1111110000110101
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110000110101
# [9095] ❌ Mismatch:
#      Input binary       : 1000001101111101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001101111101
# [9127] ❌ Mismatch:
#      Input binary       : 0111110001110100
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110001110100
# [9134] ❌ Mismatch:
#      Input binary       : 0111110100001111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110100001111
# [9175] ❌ Mismatch:
#      Input binary       : 0111111011011010
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111011011010
# [9176] ❌ Mismatch:
#      Input binary       : 1111110111010101
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110111010101
# [9180] ❌ Mismatch:
#      Input binary       : 1000001101010110
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001101010110
# [9209] ❌ Mismatch:
#      Input binary       : 0111111100110101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111100110101
# [9210] ❌ Mismatch:
#      Input binary       : 0111110110001110
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110110001110
# [9231] ❌ Mismatch:
#      Input binary       : 0000001100110001
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001100110001
# [9240] ❌ Mismatch:
#      Input binary       : 1000000111100100
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000111100100
# [9242] ❌ Mismatch:
#      Input binary       : 1000001001111000
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001001111000
# [9256] ❌ Mismatch:
#      Input binary       : 1000000011010101
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000011010101
# [9264] ❌ Mismatch:
#      Input binary       : 1000001001011011
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001001011011
# [9266] ❌ Mismatch:
#      Input binary       : 0000000100011111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000100011111
# [9269] ❌ Mismatch:
#      Input binary       : 0111111001111011
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111001111011
# [9306] ❌ Mismatch:
#      Input binary       : 1111111101010010
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111101010010
# [9326] ❌ Mismatch:
#      Input binary       : 1111110110101101
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110110101101
# [9332] ❌ Mismatch:
#      Input binary       : 0000000110100110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000110100110
# [9353] ❌ Mismatch:
#      Input binary       : 0000000000101101
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000000101101
# [9360] ❌ Mismatch:
#      Input binary       : 1111111000111110
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111000111110
# [9361] ❌ Mismatch:
#      Input binary       : 0111111110100100
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111110100100
# [9390] ❌ Mismatch:
#      Input binary       : 1111110100010001
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110100010001
# [9399] ❌ Mismatch:
#      Input binary       : 0000000110111000
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000110111000
# [9429] ❌ Mismatch:
#      Input binary       : 0111111010000000
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111010000000
# [9436] ❌ Mismatch:
#      Input binary       : 0111111100001110
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111100001110
# [9442] ❌ Mismatch:
#      Input binary       : 1000000010001100
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000010001100
# [9450] ❌ Mismatch:
#      Input binary       : 1111110101110000
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110101110000
# [9453] ❌ Mismatch:
#      Input binary       : 1111110110000111
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110110000111
# [9455] ❌ Mismatch:
#      Input binary       : 0000000000000011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000000000011
# [9493] ❌ Mismatch:
#      Input binary       : 0000001100100010
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001100100010
# [9505] ❌ Mismatch:
#      Input binary       : 1000001111100010
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001111100010
# [9512] ❌ Mismatch:
#      Input binary       : 0000001100111100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001100111100
# [9514] ❌ Mismatch:
#      Input binary       : 1000000101111110
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000101111110
# [9558] ❌ Mismatch:
#      Input binary       : 0000001100000100
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001100000100
# [9612] ❌ Mismatch:
#      Input binary       : 0111110111010111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110111010111
# [9620] ❌ Mismatch:
#      Input binary       : 1111110110010110
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110110010110
# [9622] ❌ Mismatch:
#      Input binary       : 1111111001101010
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111001101010
# [9645] ❌ Mismatch:
#      Input binary       : 0000000011111001
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000011111001
# [9647] ❌ Mismatch:
#      Input binary       : 0111110010100000
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110010100000
# [9682] ❌ Mismatch:
#      Input binary       : 1000000101011111
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000101011111
# [9707] ❌ Mismatch:
#      Input binary       : 1000000010101110
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000010101110
# [9719] ❌ Mismatch:
#      Input binary       : 0111111110001111
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111110001111
# [9726] ❌ Mismatch:
#      Input binary       : 0000001011000011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001011000011
# [9749] ❌ Mismatch:
#      Input binary       : 0111111000000001
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111000000001
# [9755] ❌ Mismatch:
#      Input binary       : 0111110010100001
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110010100001
# [9764] ❌ Mismatch:
#      Input binary       : 1000001100111111
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001100111111
# [9774] ❌ Mismatch:
#      Input binary       : 0000001001101110
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001001101110
# [9776] ❌ Mismatch:
#      Input binary       : 0111110000110010
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110000110010
# [9810] ❌ Mismatch:
#      Input binary       : 0000001110001011
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000001110001011
# [9825] ❌ Mismatch:
#      Input binary       : 0111111001100100
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111001100100
# [9840] ❌ Mismatch:
#      Input binary       : 1000001010011010
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000001010011010
# [9849] ❌ Mismatch:
#      Input binary       : 1111110000010000
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111110000010000
# [9861] ❌ Mismatch:
#      Input binary       : 0111110110000101
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111110110000101
# [9868] ❌ Mismatch:
#      Input binary       : 0000000111001111
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000111001111
# [9884] ❌ Mismatch:
#      Input binary       : 1111111100010100
#      Float16 value       : -inf
#      Custom binary       : 1111110000000000
#      Numpy binary        : 1111111100010100
# [9919] ❌ Mismatch:
#      Input binary       : 1000000101010111
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000101010111
# [9939] ❌ Mismatch:
#      Input binary       : 0000000000100101
#      Float16 value       : 0.0
#      Custom binary       : 0000000000000000
#      Numpy binary        : 0000000000100101
# [9957] ❌ Mismatch:
#      Input binary       : 0111111010001100
#      Float16 value       : inf
#      Custom binary       : 0111110000000000
#      Numpy binary        : 0111111010001100
# [9970] ❌ Mismatch:
#      Input binary       : 1000000101010111
#      Float16 value       : -0.0
#      Custom binary       : 1000000000000000
#      Numpy binary        : 1000000101010111

# %%
import utils as mu

x = [1.0, 2.5, 4.0, 7.0, 0.0]
y = [0.0, -1.0, -4.0, -2.0, 1.0]

print(mu.mean(x))
print(mu.var(x))
print(mu.rms(x))
print(mu.diff(x))
print(mu.xcorr(x, y))
print(mu.unwrap([0, np.pi/2, np.pi, -3*np.pi/4, -np.pi]))
print(mu.atan2(x, y))
